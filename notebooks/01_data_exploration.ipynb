# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("../data/processed/processed_data.csv")
# Out:
# C:\Users\neba\AppData\Local\Temp\ipykernel_21092\2305556187.py:1: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("../data/processed/processed_data.csv")

# %%
data.head()
# Out:
#    UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered  \
# 0               145249     12827       2015-03-01             True
# 1               145249     12827       2015-05-01             True
# 2               145249     12827       2015-07-01             True
# 3               145255     12827       2015-05-01             True
# 4               145255     12827       2015-07-01             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...            CoverGroup              Section  \
# 0  Current account  ...  Comprehensive - Taxi  Motor Comprehensive
# ...

# %% [markdown]
# # Step 3: Data Summarization

# %%
# Descriptive statistics for numerical features
data.describe()
# Out:
#        UnderwrittenCoverID      PolicyID    PostalCode        mmcode  \
# count         1.000098e+06  1.000098e+06  1.000098e+06  9.995460e+05
# mean          1.048175e+05  7.956682e+03  3.020601e+03  5.487770e+07
# std           6.329371e+04  5.290039e+03  2.649854e+03  1.360381e+07
# min           1.000000e+00  1.400000e+01  1.000000e+00  4.041200e+06
# 25%           5.514300e+04  4.500000e+03  8.270000e+02  6.005692e+07
# 50%           9.408300e+04  7.071000e+03  2.000000e+03  6.005842e+07
# 75%           1.391900e+05  1.107700e+04  4.180000e+03  6.005842e+07
# max           3.011750e+05  2.324600e+04  9.870000e+03  6.506535e+07
#
#        RegistrationYear      Cylinders  cubiccapacity      kilowatts  \
# count      1.000098e+06  999546.000000  999546.000000  999546.000000
# mean       2.010225e+03       4.046642    2466.743258      97.207919
# std        3.261391e+00       0.294020     442.800640      19.393256
# ...

# %% [markdown]
# The above output shows the summary statistics for numerical columns such as `TotalPremium`, `TotalClaims`, etc. We can observe the mean, median, standard deviation, and other important statistics.
#
# Next, let's check the data types of each column to ensure proper formatting.

# %%
# Check data types of each column
data.dtypes
# Out:
# UnderwrittenCoverID           int64
# PolicyID                      int64
# TransactionMonth             object
# IsVATRegistered                bool
# Citizenship                  object
# LegalType                    object
# Title                        object
# Language                     object
# Bank                         object
# AccountType                  object
# MaritalStatus                object
# Gender                       object
# Country                      object
# Province                     object
# PostalCode                    int64
# MainCrestaZone               object
# SubCrestaZone                object
# ItemType                     object
# mmcode                      float64
# VehicleType                  object
# RegistrationYear              int64
# make                         object
# Model                        object
# Cylinders                   float64
# cubiccapacity               float64
# kilowatts                   float64
# ...

# %% [markdown]
# # Step 4: Data Quality Assessment
# We will now check for missing values in the dataset to assess its quality.

# %%
# Check for missing values
data.isnull().sum()
# Out:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                         145961
# AccountType                   40232
# MaritalStatus                     0
# Gender                            0
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                          552
# VehicleType                       0
# RegistrationYear                  0
# make                            552
# Model                             0
# Cylinders                       552
# cubiccapacity                   552
# kilowatts                       552
# ...

# %% [markdown]
# Drop Columns with High Missing Data
# We remove columns with more than 50% missing values to ensure data quality.

# %%
# Define the threshold for dropping columns
threshold = len(data) * 0.5  # 50% of the total rows

# Drop columns with more than 50% missing values
columns_to_drop = data.columns[data.isnull().sum() > threshold]
data = data.drop(columns=columns_to_drop)

# Print the columns that were dropped and the remaining columns
print(f"Dropped columns: {list(columns_to_drop)}")
print(f"Remaining columns: {data.columns}")
# Out:
# Dropped columns: ['WrittenOff', 'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet']
# Remaining columns: Index(['UnderwrittenCoverID', 'PolicyID', 'TransactionMonth',
#        'IsVATRegistered', 'Citizenship', 'LegalType', 'Title', 'Language',
#        'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province',
#        'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode',
#        'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders',
#        'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors',
#        'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser',
#        'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'SumInsured',
#        'TermFrequency', 'CalculatedPremiumPerTerm', 'ExcessSelected',
#        'CoverCategory', 'CoverType', 'CoverGroup', 'Section', 'Product',
#        'StatutoryClass', 'StatutoryRiskType', 'TotalPremium', 'TotalClaims',
# ...

# %% [markdown]
# Imputing Missing Data
# Numerical Columns
# Filled missing values in numerical columns with the median.

# %%
# Fill missing values for numerical columns with median
numerical_cols = data.select_dtypes(include=["float64", "int64"]).columns
data[numerical_cols] = data[numerical_cols].fillna(data[numerical_cols].median())

# %% [markdown]
# Categorical Columns
# Filled missing values in categorical columns with the string 'Unknown'

# %%
# Fill missing values for categorical columns with 'Unknown'
categorical_cols = data.select_dtypes(include=["object"]).columns
data[categorical_cols] = data[categorical_cols].fillna('Unknown')

# %% [markdown]
# Verify Data Quality
# After handling missing values, I verify that there are no remaining missing values.

# %%
# Verify that there are no missing values
print(data.isnull().sum())
# Out:
# UnderwrittenCoverID         0
# PolicyID                    0
# TransactionMonth            0
# IsVATRegistered             0
# Citizenship                 0
# LegalType                   0
# Title                       0
# Language                    0
# Bank                        0
# AccountType                 0
# MaritalStatus               0
# Gender                      0
# Country                     0
# Province                    0
# PostalCode                  0
# MainCrestaZone              0
# SubCrestaZone               0
# ItemType                    0
# mmcode                      0
# VehicleType                 0
# RegistrationYear            0
# make                        0
# Model                       0
# Cylinders                   0
# cubiccapacity               0
# kilowatts                   0
# bodytype                    0
# NumberOfDoors               0
# VehicleIntroDate            0
# CustomValueEstimate         0
# AlarmImmobiliser            0
# ...

# %%
# Save the cleaned data
data.to_csv("../data/processed/cleaned_data.csv", index=False)

# %% [markdown]
# Univariate Analysis
# Distribution of Numerical Variables
# A histogram is used for numerical columns to visualize their distributions.

# %%
import matplotlib.pyplot as plt

# Plot histograms for numerical columns
numerical_cols = data.select_dtypes(include=["float64", "int64"]).columns
data[numerical_cols].hist(figsize=(15, 10), bins=30)
plt.suptitle("Distribution of Numerical Variables")
plt.show()

# %% [markdown]
# Distribution of Categorical Variables

# %%
# Plot bar charts for categorical columns
categorical_cols = data.select_dtypes(include=["object"]).columns
for col in categorical_cols:
    data[col].value_counts().plot(kind='bar', figsize=(10, 5))
    plt.title(f"Distribution of {col}")
    plt.show()

# %% [markdown]
# Correlations and Associations
# Relationships between TotalPremium and TotalClaims as a function of ZipCode.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric columns for correlation analysis
numeric_cols = data.select_dtypes(include=["float64", "int64"]).columns

# Compute the correlation matrix
corr_matrix = data[numeric_cols].corr()

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Matrix of Numerical Features")
plt.show()

# %% [markdown]
# Trends Over Geography
# Trends in insurance cover types, premiums, and auto makes across different regions.

# %%
# Group by Province and calculate mean TotalPremium
province_trends = data.groupby("Province")["TotalPremium"].mean().sort_values()
province_trends.plot(kind='bar', figsize=(10, 5))
plt.title("Average TotalPremium by Province")
plt.ylabel("Average TotalPremium")
plt.show()

# %% [markdown]
# Outlier Detection

# %%
# Box plots for numerical columns
for col in numerical_cols:
    plt.figure(figsize=(8, 4))
    sns.boxplot(data=data, x=col)
    plt.title(f"Box Plot for {col}")
    plt.show()

# %%
# Plot ClaimsRatio distribution
sns.histplot(data=data, x="ClaimsRatio", kde=True, bins=30, color="purple")
plt.title("Distribution of Claims Ratio")
plt.show()

# %%
# Scatter plot for Premium vs Claims by Vehicle Type
sns.scatterplot(data=data, x="TotalPremium", y="TotalClaims", hue="VehicleType", alpha=0.7)
plt.title("TotalPremium vs TotalClaims by Vehicle Type")
plt.show()

# %%
# Premium trends over RegistrationYear
yearly_premiums = data.groupby("RegistrationYear")["TotalPremium"].mean()
yearly_premiums.plot(kind="line", figsize=(10, 5), marker="o", color="green")
plt.title("Average TotalPremium by Registration Year")
plt.ylabel("Average TotalPremium")
plt.show()
